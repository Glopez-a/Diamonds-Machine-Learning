# %%
import pandas as pd



from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Import training and test datasets

# %%
df = pd.read_csv("../data/df_baseline.csv")
test = pd.read_csv("../data/tests/diamonds_test.csv")

# %% [markdown]
# ## Analisis of both datasets

# %%
df.describe()
# Out:
#               price         carat         depth         table             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean    3928.444469      0.797706     61.752841     57.446133      5.729392
# std     3992.416147      0.475544      1.431725      2.233535      1.124453
# min      326.000000      0.200000     43.000000     43.000000      0.000000
# 25%      945.000000      0.400000     61.000000     56.000000      4.710000
# 50%     2397.000000      0.700000     61.800000     57.000000      5.690000
# 75%     5331.000000      1.040000     62.500000     59.000000      6.540000
# max    18823.000000      4.500000     79.000000     95.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# max       58.900000      8.060000

# %%
test.describe()
# Out:
#                  id         carat         depth         table             x  \
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean    6742.000000      0.798642     61.739095     57.490337      5.736454
# std     3892.928525      0.469399      1.435310      2.237109      1.113671
# min        0.000000      0.200000     50.800000     51.000000      0.000000
# 25%     3371.000000      0.400000     61.000000     56.000000      4.730000
# 50%     6742.000000      0.700000     61.900000     57.000000      5.700000
# 75%    10113.000000      1.040000     62.500000     59.000000      6.530000
# max    13484.000000      5.010000     79.000000     73.000000     10.740000
#
#                   y             z
# count  13485.000000  13485.000000
# mean       5.739648      3.543474
# std        1.128507      0.731005
# min        0.000000      0.000000
# 25%        4.730000      2.920000
# 50%        5.720000      3.530000
# 75%        6.530000      4.040000
# max       31.800000     31.800000

# %%
df
# Out:
#        price  carat        city  depth  table     x     y     z clarity color  \
# 0        505   0.32    Kimberly   63.0   57.0  4.35  4.38  2.75     VS2     H
# 1       2686   0.71   Las Vegas   65.5   55.0  5.62  5.53  3.65     VS1     G
# 2        738   0.41    Kimberly   63.8   56.0  4.68  4.72  3.00     SI1     D
# 3       9057   1.52    Tel Aviv   61.2   57.0  7.45  7.39  4.54     SI2     F
# 4        557   0.31      Zurich   61.8   54.2  4.33  4.37  2.69     VS1     H
# ...      ...    ...         ...    ...    ...   ...   ...   ...     ...   ...
# 40450   1116   0.35   Amsterdam   62.2   58.0  4.52  4.45  2.79      IF     G
# 40451    975   0.40  Luxembourg   62.4   55.0  4.74  4.71  2.95     VS2     E
# 40452   8572   1.57    Tel Aviv   61.1   61.0  7.46  7.43  4.55     SI2     G
# 40453   5154   0.73       Paris   61.4   56.0  5.80  5.81  3.56    VVS1     F
# 40454   1148   0.39      London   61.7   57.0  4.68  4.71  2.89    VVS1     F
#
#              cut
# 0      Very Good
# 1           Fair
# 2           Good
# 3          Ideal
# 4          Ideal
# ...          ...
# 40450    Premium
# 40451      Ideal
# 40452    Premium
# 40453      Ideal
# 40454      Ideal
#
# [40455 rows x 11 columns]

# %%
df.head(10)
# Out:
#    price  carat       city  depth  table     x     y     z clarity color  \
# 0    505   0.32   Kimberly   63.0   57.0  4.35  4.38  2.75     VS2     H
# 1   2686   0.71  Las Vegas   65.5   55.0  5.62  5.53  3.65     VS1     G
# 2    738   0.41   Kimberly   63.8   56.0  4.68  4.72  3.00     SI1     D
# 3   9057   1.52   Tel Aviv   61.2   57.0  7.45  7.39  4.54     SI2     F
# 4    557   0.31     Zurich   61.8   54.2  4.33  4.37  2.69     VS1     H
# 5   6741   1.14    Antwerp   61.7   56.0  6.71  6.75  4.15     SI1     G
# 6   1040   0.44  Las Vegas   62.3   59.0  4.88  4.84  3.03     SI1     E
# 7   4284   1.02   Tel Aviv   58.0   58.0  6.84  6.60  3.90     SI1     I
# 8   3101   0.93     Madrid   62.3   57.0  6.20  6.22  3.87     SI2     I
# 9  14507   1.51      Paris   60.1   58.0  7.48  7.45  4.49     VS1     G
#
#          cut
# 0  Very Good
# 1       Fair
# 2       Good
# 3      Ideal
# 4      Ideal
# 5      Ideal
# 6    Premium
# 7    Premium
# 8      Ideal
# 9    Premium

# %%
test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city
# 0          Amsterdam
# 1              Surat
# 2           Kimberly
# 3           Kimberly
# 4          Amsterdam
# ...              ...
# 13480      Amsterdam
# 13481  New York City
# 13482       Tel Aviv
# 13483          Surat
# 13484  New York City
#
# [13485 rows x 11 columns]

# %% [markdown]
# ## Preprocessing

# %%
# Eliminate 'x' outliers
df = df[df['x'] > 0.05]
df = df[df['x'] < 90]

# %%
# Eliminate 'y' outliers
df = df[df['y'] > 0.05]
df = df[df['y'] < 50]

# %%
# Eliminate 'y' outliers
df = df[df['z'] > 2]

# %%
# Eliminate 'table' outliers
df = df[df['table'] < 80]

# %%
# Transform x,y,z in the test dataset, for the outliers ("input errors")
test.loc[test['x'] < 0.2, 'x'] = 4.73

# %%
test.loc[test['y'] < 0.2, 'y'] = 4.73

# %%
test.loc[test['z'] < 0.2, 'z'] = 2.91

# %% [markdown]
# ## Feaure engineering

# %%
# Create variable ratio Length / Width
df['L/W ratio'] = df['x'] / df['y']

# %%
test['L/W ratio'] = test['x'] / test['y']

# %%
# Create variable with the relation between carat, table and depth
df['V'] = df['carat'] / df['table'] * df['depth']

# %%
test['V'] = test['carat'] / test['table'] * test['depth']

# %%
# Function to create a new column, bins conbining depth and table
def custom_sort(row):
    # Define the sorting logic based on the columns
    if row['depth'] > 60 and row['depth'] < 62 and row['table'] > 53 and row['table'] < 57:
        return 5
    elif row['depth'] > 58.5 and row['depth'] < 64 and row['table'] > 52 and row['table'] < 60:
        return 4
    elif row['depth'] > 57.5 and row['depth'] < 64.5 and row['table'] > 51 and row['table'] < 65:
        return 3
    elif row['depth'] > 56.5 and row['depth'] < 67 and row['table'] > 50 and row['table'] < 67:
        return 2
    else:
        return 1

# %%
df['sorting_category'] = df.apply(custom_sort, axis=1)

df.sort_values('sorting_category')
# Out:
#        price  carat           city  depth  table     x     y     z clarity  \
# 25373   4398   1.02       Kimberly   70.6   57.0  6.08  6.01  4.27     SI1
# 10962   4320   1.45          Surat   64.8   67.0  7.16  7.00  4.64      I1
# 21180    474   0.29          Paris   62.8   44.0  4.20  4.24  2.65     VS1
# 36365    829   0.47         Madrid   67.9   56.0  4.84  4.65  3.24     SI1
# 2392    3142   1.00          Dubai   68.3   54.0  6.21  6.12  4.20     SI2
# ...      ...    ...            ...    ...    ...   ...   ...   ...     ...
# 5572    2917   0.71          Dubai   61.2   56.0  5.77  5.73  3.52     VS2
# 24137   3360   0.70      Las Vegas   61.4   55.0  5.71  5.75  3.52     VS2
# 17070   1034   0.31       Tel Aviv   61.1   56.0  4.38  4.39  2.68    VVS2
# 5560    2455   0.71         Zurich   61.9   56.0  5.68  5.72  3.53     SI1
# 12516    583   0.23  New York City   61.5   56.0  3.95  4.00  2.44    VVS2
#
#       color        cut  L/W ratio         V  sorting_category
# 25373     D       Fair   1.011647  1.263368                 1
# 10962     F       Fair   1.022857  1.402388                 1
# 21180     E  Very Good   0.990566  0.413909                 1
# 36365     E       Fair   1.040860  0.569875                 1
# 2392      G       Fair   1.014706  1.264815                 1
# ...     ...        ...        ...       ...               ...
# 5572      F      Ideal   1.006981  0.775929                 5
# 24137     D      Ideal   0.993043  0.781455                 5
# 17070     D      Ideal   0.997722  0.338232                 5
# 5560      E  Very Good   0.993007  0.784804                 5
# 12516     F  Very Good   0.987500  0.252589                 5
#
# [40435 rows x 14 columns]

# %%
test['sorting_category'] = test.apply(custom_sort, axis=1)

#test['sorting_category'] = test['sorting_category'].astype(int)
test.sort_values('sorting_category')
# Out:
#           id  carat    cut color clarity  depth  table     x     y     z  \
# 5813    5813   1.01   Fair     D     VS2   59.1   68.0  6.56  6.44  3.84
# 11225  11225   1.91   Fair     I     VS1   59.5   68.0  8.10  7.91  4.78
# 8180    8180   0.97   Fair     J     SI2   60.8   67.0  6.41  6.32  3.87
# 6062    6062   0.46   Fair     G     SI1   63.4   68.0  4.88  4.80  3.07
# 7193    7193   0.50   Good     H     VS2   56.3   65.0  5.21  5.24  2.94
# ...      ...    ...    ...   ...     ...    ...    ...   ...   ...   ...
# 10446  10446   0.40  Ideal     I    VVS2   61.8   56.0  4.76  4.79  2.95
# 1895    1895   1.21  Ideal     E     SI1   61.8   56.0  6.82  6.86  4.23
# 10452  10452   0.42  Ideal     G    VVS2   61.3   56.0  4.82  4.81  2.95
# 4919    4919   0.54  Ideal     G    VVS1   61.3   56.0  5.28  5.23  3.22
# 7945    7945   0.35  Ideal     F     VS2   61.4   54.0  4.54  4.58  2.80
#
#             city  L/W ratio         V  sorting_category
# 5813       Paris   1.018634  0.877809                 1
# 11225   Tel Aviv   1.024020  1.671250                 1
# 8180   Las Vegas   1.014241  0.880239                 1
# 6062     Antwerp   1.016667  0.428882                 1
# 7193       Surat   0.994275  0.433077                 1
# ...          ...        ...       ...               ...
# 10446     London   0.993737  0.441429                 5
# 1895     Antwerp   0.994169  1.335321                 5
# 10452     Zurich   1.002079  0.459750                 5
# 4919    Kimberly   1.009560  0.591107                 5
# 7945     Antwerp   0.991266  0.397963                 5
#
# [13485 rows x 14 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13485 entries, 0 to 13484
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                13485 non-null  int64
#  1   carat             13485 non-null  float64
#  2   cut               13485 non-null  object
#  3   color             13485 non-null  object
#  4   clarity           13485 non-null  object
#  5   depth             13485 non-null  float64
#  6   table             13485 non-null  float64
#  7   x                 13485 non-null  float64
#  8   y                 13485 non-null  float64
#  9   z                 13485 non-null  float64
#  10  city              13485 non-null  object
#  11  L/W ratio         13485 non-null  float64
#  12  V                 13485 non-null  float64
#  13  sorting_category  13485 non-null  int64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
test.describe()
# Out:
#                  id         carat         depth         table             x  \
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean    6742.000000      0.798642     61.739095     57.490337      5.737506
# std     3892.928525      0.469399      1.435310      2.237109      1.110480
# min        0.000000      0.200000     50.800000     51.000000      3.730000
# 25%     3371.000000      0.400000     61.000000     56.000000      4.730000
# 50%     6742.000000      0.700000     61.900000     57.000000      5.700000
# 75%    10113.000000      1.040000     62.500000     59.000000      6.530000
# max    13484.000000      5.010000     79.000000     73.000000     10.740000
#
#                   y             z     L/W ratio             V  \
# count  13485.000000  13485.000000  13485.000000  13485.000000
# mean       5.740700      3.544337      0.999519      0.856130
# std        1.125355      0.728534      0.012935      0.501066
# min        3.680000      1.410000      0.161950      0.196667
# 25%        4.730000      2.920000      0.992669      0.430345
# 50%        5.720000      3.530000      0.995781      0.756491
# 75%        6.530000      4.040000      1.006993      1.138259
# max       31.800000     31.800000      1.601415      5.561949
#
#        sorting_category
# count      13485.000000
# mean           3.904783
# std            0.712734
# min            1.000000
# 25%            4.000000
# 50%            4.000000
# 75%            4.000000
# max            5.000000

# %% [markdown]
# ## Enlabel categorical variables

# %%
df.loc[df['color'] == 'J', 'color'] = 1
df.loc[df['color'] == 'I', 'color'] = 2
df.loc[df['color'] == 'H', 'color'] = 3
df.loc[df['color'] == 'G', 'color'] = 4
df.loc[df['color'] == 'F', 'color'] = 5
df.loc[df['color'] == 'E', 'color'] = 6
df.loc[df['color'] == 'D', 'color'] = 7

# %%
test.loc[test['color'] == 'J', 'color'] = 1
test.loc[test['color'] == 'I', 'color'] = 2
test.loc[test['color'] == 'H', 'color'] = 3
test.loc[test['color'] == 'G', 'color'] = 4
test.loc[test['color'] == 'F', 'color'] = 5
test.loc[test['color'] == 'E', 'color'] = 6
test.loc[test['color'] == 'D', 'color'] = 7

# %%
df.loc[df['clarity'] == 'I1', 'clarity'] = 1
df.loc[df['clarity'] == 'SI2', 'clarity'] = 2
df.loc[df['clarity'] == 'SI1', 'clarity'] = 3
df.loc[df['clarity'] == 'VS2', 'clarity'] = 4
df.loc[df['clarity'] == 'VS1', 'clarity'] = 5
df.loc[df['clarity'] == 'VVS2', 'clarity'] = 6
df.loc[df['clarity'] == 'VVS1', 'clarity'] = 7
df.loc[df['clarity'] == 'IF', 'clarity'] = 8

# %%
test.loc[test['clarity'] == 'I1', 'clarity'] = 1
test.loc[test['clarity'] == 'SI2', 'clarity'] = 2
test.loc[test['clarity'] == 'SI1', 'clarity'] = 3
test.loc[test['clarity'] == 'VS2', 'clarity'] = 4
test.loc[test['clarity'] == 'VS1', 'clarity'] = 5
test.loc[test['clarity'] == 'VVS2', 'clarity'] = 6
test.loc[test['clarity'] == 'VVS1', 'clarity'] = 7
test.loc[test['clarity'] == 'IF', 'clarity'] = 8

# %%
df.loc[df['cut'] == 'Fair', 'cut'] = 1
df.loc[df['cut'] == 'Good', 'cut'] = 2
df.loc[df['cut'] == 'Very Good', 'cut'] = 3
df.loc[df['cut'] == 'Premium', 'cut'] = 4
df.loc[df['cut'] == 'Ideal', 'cut'] = 5

# %%
test.loc[test['cut'] == 'Fair', 'cut'] = 1
test.loc[test['cut'] == 'Good', 'cut'] = 2
test.loc[test['cut'] == 'Very Good', 'cut'] = 3
test.loc[test['cut'] == 'Premium', 'cut'] = 4
test.loc[test['cut'] == 'Ideal', 'cut'] = 5

# %% [markdown]
# ## Training model with GraadientBoost and GridSearch

# %%
# Defining features for training
X = df[['L/W ratio','V','carat','cut','color','clarity','depth','table','sorting_category']]
X
# Out:
#        L/W ratio         V  carat cut color clarity  depth  table  \
# 0       0.993151  0.353684   0.32   3     3       4   63.0   57.0
# 1       1.016275  0.845545   0.71   1     4       5   65.5   55.0
# 2       0.991525  0.467107   0.41   2     7       3   63.8   56.0
# 3       1.008119  1.632000   1.52   5     5       2   61.2   57.0
# 4       0.990847  0.353469   0.31   5     3       5   61.8   54.2
# ...          ...       ...    ...  ..   ...     ...    ...    ...
# 40450   1.015730  0.375345   0.35   4     4       8   62.2   58.0
# 40451   1.006369  0.453818   0.40   5     6       4   62.4   55.0
# 40452   1.004038  1.572574   1.57   4     4       2   61.1   61.0
# 40453   0.998279  0.800393   0.73   5     5       7   61.4   56.0
# 40454   0.993631  0.422158   0.39   5     5       7   61.7   57.0
#
#        sorting_category
# 0                     4
# 1                     2
# 2                     4
# 3                     4
# 4                     5
# ...                 ...
# 40450                 4
# 40451                 4
# 40452                 3
# 40453                 5
# 40454                 4
#
# [40435 rows x 9 columns]

# %%
y = df['price']

# %%
# GradientBoost model
model = GradientBoostingRegressor()

# %%
# Defining parameters of grid, to check wich one fits better with this case
param_grid = {'n_estimators': [16, 32, 64, 128, 256, 512],
              'max_depth': [2, 4, 8, 16]}

# %%
grid_search = GridSearchCV(model,
                           param_grid,
                           cv=5,
                           verbose=3,
                           scoring='neg_root_mean_squared_error',
                           n_jobs=-1)

# %%
# Training my GradientBoost model with grid_search
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [2, 4, 8, 16],
#                          'n_estimators': [16, 32, 64, 128, 256, 512]},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
print('\n')
print('Best hyperparameters: ', grid_search.best_params_, '\n')
print('Best score: ', -grid_search.best_score_, '\n')
# Out:
# Best hyperparameters:  {'max_depth': 8, 'n_estimators': 64}
#
# Best score:  517.3956640958106

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# GradientBoostingRegressor(max_depth=8, n_estimators=64)

# %%
# Defining features for test
test = test[['L/W ratio','V','carat','cut','color','clarity','depth','table','sorting_category']]

# %%
predictions = best_model.predict(test)

# %%
result = pd.DataFrame({'id': range(0, len(predictions)), 'price': predictions})
result
# Out:
#           id         price
# 0          0   2882.817738
# 1          1   5505.842918
# 2          2  10010.836519
# 3          3   3965.504462
# 4          4   1606.019377
# ...      ...           ...
# 13480  13480   1677.143853
# 13481  13481   2457.311350
# 13482  13482   2981.521924
# 13483  13483   2083.791885
# 13484  13484    853.002320
#
# [13485 rows x 2 columns]

# %%
result.to_csv("../submissions/submision_final_model.csv", index=False)
# Out:
# [CV 3/5] END ..max_depth=2, n_estimators=32;, score=-1215.345 total time=   1.3s
# [CV 1/5] END ..max_depth=2, n_estimators=128;, score=-735.269 total time=   4.4s
# [CV 4/5] END ..max_depth=2, n_estimators=256;, score=-689.463 total time=   8.7s
# [CV 3/5] END ..max_depth=4, n_estimators=16;, score=-1142.235 total time=   1.1s
# [CV 1/5] END ...max_depth=4, n_estimators=32;, score=-696.436 total time=   2.0s
# [CV 4/5] END ...max_depth=4, n_estimators=32;, score=-707.159 total time=   2.1s
# [CV 2/5] END ...max_depth=4, n_estimators=64;, score=-549.006 total time=   3.9s
# [CV 5/5] END ...max_depth=4, n_estimators=64;, score=-551.923 total time=   3.8s
# [CV 1/5] END ..max_depth=4, n_estimators=256;, score=-526.628 total time=  15.6s
# [CV 4/5] END ..max_depth=4, n_estimators=512;, score=-539.947 total time=  30.2s
# [CV 2/5] END ..max_depth=8, n_estimators=256;, score=-517.562 total time=  29.2s
# [CV 5/5] END ..max_depth=8, n_estimators=512;, score=-528.208 total time=  59.8s
# [CV 2/5] END .max_depth=16, n_estimators=256;, score=-623.751 total time=  57.7s
# [CV 3/5] END ..max_depth=2, n_estimators=16;, score=-1628.770 total time=   0.7s
# [CV 3/5] END ...max_depth=2, n_estimators=64;, score=-913.232 total time=   2.1s
# [CV 4/5] END ..max_depth=2, n_estimators=128;, score=-746.983 total time=   4.2s
# [CV 2/5] END ..max_depth=2, n_estimators=512;, score=-622.056 total time=  17.4s
# [CV 2/5] END ..max_depth=4, n_estimators=128;, score=-519.828 total time=   7.8s
# [CV 4/5] END ..max_depth=4, n_estimators=256;, score=-545.401 total time=  16.1s
# [CV 3/5] END ...max_depth=8, n_estimators=16;, score=-929.203 total time=   1.8s
# [CV 1/5] END ...max_depth=8, n_estimators=32;, score=-539.444 total time=   3.7s
# [CV 5/5] END ...max_depth=8, n_estimators=32;, score=-539.304 total time=   3.6s
# [CV 3/5] END ...max_depth=8, n_estimators=64;, score=-517.335 total time=   7.2s
# [CV 3/5] END ..max_depth=8, n_estimators=128;, score=-525.226 total time=  15.0s
# [CV 1/5] END ..max_depth=8, n_estimators=512;, score=-524.732 total time= 1.0min
# [CV 1/5] END .max_depth=16, n_estimators=128;, score=-619.271 total time=  28.7s
# [CV 4/5] END .max_depth=16, n_estimators=256;, score=-625.868 total time=  56.6s
# [CV 2/5] END ..max_depth=2, n_estimators=16;, score=-1628.403 total time=   0.6s
# [CV 5/5] END ..max_depth=2, n_estimators=32;, score=-1157.251 total time=   1.3s
# [CV 3/5] END ..max_depth=2, n_estimators=128;, score=-756.201 total time=   4.4s
# [CV 1/5] END ..max_depth=2, n_estimators=512;, score=-625.479 total time=  18.0s
# [CV 1/5] END ..max_depth=4, n_estimators=128;, score=-532.857 total time=   8.0s
# [CV 5/5] END ..max_depth=4, n_estimators=256;, score=-517.777 total time=  16.1s
# [CV 4/5] END ...max_depth=8, n_estimators=16;, score=-926.383 total time=   1.8s
# [CV 2/5] END ...max_depth=8, n_estimators=32;, score=-544.107 total time=   3.6s
# [CV 4/5] END ...max_depth=8, n_estimators=32;, score=-557.496 total time=   3.6s
# [CV 2/5] END ...max_depth=8, n_estimators=64;, score=-508.788 total time=   7.2s
# [CV 2/5] END ..max_depth=8, n_estimators=128;, score=-513.328 total time=  14.9s
# [CV 5/5] END ..max_depth=8, n_estimators=256;, score=-523.356 total time=  29.3s
# [CV 3/5] END ..max_depth=16, n_estimators=16;, score=-948.432 total time=   3.6s
# [CV 1/5] END ..max_depth=16, n_estimators=32;, score=-632.433 total time=   7.1s
# [CV 4/5] END ..max_depth=16, n_estimators=32;, score=-634.546 total time=   7.2s
# [CV 2/5] END ..max_depth=16, n_estimators=64;, score=-623.434 total time=  14.2s
# [CV 2/5] END .max_depth=16, n_estimators=128;, score=-623.074 total time=  28.7s
# [CV 5/5] END .max_depth=16, n_estimators=256;, score=-620.319 total time=  56.8s
# [CV 5/5] END ..max_depth=2, n_estimators=16;, score=-1569.196 total time=   0.7s
# [CV 2/5] END ...max_depth=2, n_estimators=64;, score=-868.838 total time=   2.2s
# [CV 1/5] END ..max_depth=2, n_estimators=256;, score=-667.096 total time=   8.4s
# [CV 4/5] END ..max_depth=2, n_estimators=512;, score=-646.532 total time=  17.3s
# [CV 2/5] END ..max_depth=4, n_estimators=256;, score=-513.740 total time=  16.8s
# [CV 5/5] END ..max_depth=4, n_estimators=512;, score=-518.963 total time=  30.9s
# [CV 3/5] END ..max_depth=8, n_estimators=256;, score=-530.812 total time=  29.3s
# [CV 1/5] END ..max_depth=16, n_estimators=16;, score=-941.815 total time=   3.8s
# [CV 4/5] END ..max_depth=16, n_estimators=16;, score=-934.166 total time=   3.6s
# [CV 2/5] END ..max_depth=16, n_estimators=32;, score=-635.886 total time=   7.2s
# [CV 5/5] END ..max_depth=16, n_estimators=32;, score=-629.716 total time=   7.4s
# [CV 3/5] END ..max_depth=16, n_estimators=64;, score=-612.815 total time=  14.1s
# [CV 3/5] END .max_depth=16, n_estimators=128;, score=-612.945 total time=  28.7s
# [CV 1/5] END .max_depth=16, n_estimators=512;, score=-618.933 total time= 1.7min
# [CV 1/5] END ..max_depth=2, n_estimators=32;, score=-1189.527 total time=   1.1s
# [CV 4/5] END ...max_depth=2, n_estimators=64;, score=-885.349 total time=   2.2s
# [CV 3/5] END ..max_depth=2, n_estimators=256;, score=-691.450 total time=   8.7s
# [CV 5/5] END ..max_depth=2, n_estimators=512;, score=-634.787 total time=  17.3s
# [CV 3/5] END ..max_depth=4, n_estimators=256;, score=-533.482 total time=  16.1s
# [CV 1/5] END ...max_depth=8, n_estimators=16;, score=-922.721 total time=   1.8s
# [CV 2/5] END ...max_depth=8, n_estimators=16;, score=-951.736 total time=   1.8s
# [CV 5/5] END ...max_depth=8, n_estimators=16;, score=-924.575 total time=   1.8s
# [CV 3/5] END ...max_depth=8, n_estimators=32;, score=-545.496 total time=   3.6s
# [CV 1/5] END ...max_depth=8, n_estimators=64;, score=-510.144 total time=   7.2s
# [CV 4/5] END ...max_depth=8, n_estimators=64;, score=-534.355 total time=   7.2s
# [CV 5/5] END ..max_depth=8, n_estimators=128;, score=-518.100 total time=  14.6s
# [CV 3/5] END ..max_depth=8, n_estimators=512;, score=-534.448 total time=  59.6s
# [CV 4/5] END .max_depth=16, n_estimators=128;, score=-626.998 total time=  28.8s
# [CV 2/5] END .max_depth=16, n_estimators=512;, score=-625.995 total time= 1.7min
# [CV 2/5] END ..max_depth=2, n_estimators=32;, score=-1190.874 total time=   1.1s
# [CV 5/5] END ...max_depth=2, n_estimators=64;, score=-850.922 total time=   2.1s
# [CV 2/5] END ..max_depth=2, n_estimators=256;, score=-660.550 total time=   9.3s
# [CV 1/5] END ..max_depth=4, n_estimators=16;, score=-1128.692 total time=   1.1s
# [CV 2/5] END ..max_depth=4, n_estimators=16;, score=-1157.112 total time=   1.0s
# [CV 4/5] END ..max_depth=4, n_estimators=16;, score=-1138.482 total time=   1.0s
# [CV 2/5] END ...max_depth=4, n_estimators=32;, score=-692.715 total time=   2.3s
# [CV 5/5] END ...max_depth=4, n_estimators=32;, score=-674.607 total time=   2.4s
# [CV 3/5] END ...max_depth=4, n_estimators=64;, score=-572.985 total time=   4.2s
# [CV 3/5] END ..max_depth=4, n_estimators=128;, score=-539.585 total time=   8.1s
# [CV 2/5] END ..max_depth=4, n_estimators=512;, score=-507.701 total time=  31.3s
# [CV 1/5] END ..max_depth=8, n_estimators=128;, score=-513.159 total time=  14.8s
# [CV 4/5] END ..max_depth=8, n_estimators=256;, score=-539.130 total time=  29.1s
# [CV 2/5] END ..max_depth=16, n_estimators=16;, score=-971.262 total time=   3.6s
# [CV 5/5] END ..max_depth=16, n_estimators=16;, score=-938.056 total time=   3.5s
# [CV 3/5] END ..max_depth=16, n_estimators=32;, score=-627.857 total time=   7.2s
# [CV 1/5] END ..max_depth=16, n_estimators=64;, score=-620.295 total time=  14.1s
# [CV 4/5] END ..max_depth=16, n_estimators=64;, score=-627.162 total time=  13.8s
# [CV 5/5] END .max_depth=16, n_estimators=128;, score=-620.983 total time=  28.1s
# [CV 3/5] END .max_depth=16, n_estimators=512;, score=-612.815 total time= 1.6min
# [CV 1/5] END ..max_depth=2, n_estimators=16;, score=-1606.604 total time=   0.6s
# [CV 4/5] END ..max_depth=2, n_estimators=32;, score=-1177.656 total time=   1.3s
# [CV 2/5] END ..max_depth=2, n_estimators=128;, score=-723.811 total time=   4.4s
# [CV 5/5] END ..max_depth=2, n_estimators=256;, score=-664.560 total time=   8.9s
# [CV 5/5] END ..max_depth=4, n_estimators=16;, score=-1119.309 total time=   1.1s
# [CV 3/5] END ...max_depth=4, n_estimators=32;, score=-710.842 total time=   2.1s
# [CV 1/5] END ...max_depth=4, n_estimators=64;, score=-564.584 total time=   4.7s
# [CV 4/5] END ...max_depth=4, n_estimators=64;, score=-583.205 total time=   4.0s
# [CV 5/5] END ..max_depth=4, n_estimators=128;, score=-524.813 total time=   8.1s
# [CV 3/5] END ..max_depth=4, n_estimators=512;, score=-531.159 total time=  30.5s
# [CV 4/5] END ..max_depth=8, n_estimators=128;, score=-535.556 total time=  14.8s
# [CV 2/5] END ..max_depth=8, n_estimators=512;, score=-522.315 total time=  59.4s
# [CV 5/5] END ..max_depth=16, n_estimators=64;, score=-621.899 total time=  14.0s
# [CV 1/5] END .max_depth=16, n_estimators=256;, score=-620.136 total time=  57.5s
# [CV 4/5] END .max_depth=16, n_estimators=512;, score=-628.377 total time= 1.5min
# [CV 4/5] END ..max_depth=2, n_estimators=16;, score=-1590.346 total time=   0.6s
# [CV 1/5] END ...max_depth=2, n_estimators=64;, score=-890.957 total time=   2.2s
# [CV 5/5] END ..max_depth=2, n_estimators=128;, score=-711.948 total time=   4.5s
# [CV 3/5] END ..max_depth=2, n_estimators=512;, score=-646.416 total time=  17.6s
# [CV 4/5] END ..max_depth=4, n_estimators=128;, score=-557.480 total time=   7.9s
# [CV 1/5] END ..max_depth=4, n_estimators=512;, score=-528.682 total time=  31.3s
# [CV 5/5] END ...max_depth=8, n_estimators=64;, score=-516.356 total time=   7.5s
# [CV 1/5] END ..max_depth=8, n_estimators=256;, score=-518.458 total time=  29.6s
# [CV 4/5] END ..max_depth=8, n_estimators=512;, score=-542.344 total time= 1.0min
# [CV 3/5] END .max_depth=16, n_estimators=256;, score=-614.376 total time=  57.1s
# [CV 5/5] END .max_depth=16, n_estimators=512;, score=-621.635 total time= 1.5min
